# %% [markdown]
# <a href="https://colab.research.google.com/github/HanSong19/PALS0039-Introduction-to-Deep-Learning-for-Speech-and-Language-Processing-/blob/main/PALS0039_Ex_2_1_answers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![PALS0039 Logo](https://www.phon.ucl.ac.uk/courses/pals0039/images/pals0039logo.png)](https://www.phon.ucl.ac.uk/courses/pals0039/)
#
# #Exercise 2.1 Pandas practice

# %% [markdown]
# (a) Use pandas to read the **tab-separated** file stored at this URL into a `DataFrame`:
# * [https://www.phon.ucl.ac.uk/courses/pals0039/data/exercise_02/renewable_energy.tsv](https://www.phon.ucl.ac.uk/courses/pals0039/data/exercise_02/renewable_energy.tsv)
#
# Hint: It is possible to use the Pandas [`read_csv` function](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) configured with the correct `delimiter` argument.
#
# This data describes renewable energy usage as a percentage of total energy consumption between the years 1990 and 2018, broken down by country (source: [World Bank](https://data.worldbank.org/)).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#(a)
energy_data = pd.read_csv("https://www.phon.ucl.ac.uk/courses/pals0039/data/exercise_02/renewable_energy.tsv", delimiter="\t")
type(energy_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# (b) Display the first 10 rows of the table:

# %%
#(b)
energy_data.iloc[:10]
# Out:
#                   Country Name Country Code       1990       1991       1992  \
# 0                        Aruba          ABW   0.268747   0.234955   0.238778
# 1  Africa Eastern and Southern          AFE  61.625965  62.876319  64.636541
# 2                  Afghanistan          AFG  15.924532  17.036444  26.521629
# 3   Africa Western and Central          AFW  86.082214  85.443014  83.983071
# 4                       Angola          AGO  72.255252  71.888639  72.723283
# 5                      Albania          ALB  25.518088  32.998174  46.813329
# 6                      Andorra          AND  14.273550  14.273550  14.308754
# 7                   Arab World          ARB   7.344358   7.284093   6.912966
# 8         United Arab Emirates          ARE   0.000000   0.000000   0.188369
# 9                    Argentina          ARG   8.922907   8.748184   9.471650
#
#         1993       1994       1995       1996       1997  ...       2009  \
# ...

# %% [markdown]
# (c) Set the `Country Code` column as the index of the DataFrame and remove the `Country Name` column (use this updated DataFrame in subsequent questions)

# %%
#(c)
energy_data = energy_data.set_index("Country Code")
energy_data = energy_data.drop(columns="Country Name")
energy_data
# Out:
#                    1990       1991       1992       1993       1994  \
# Country Code
# ABW            0.268747   0.234955   0.238778   0.195134   0.183241
# AFE           61.625965  62.876319  64.636541  65.291676  65.379764
# AFG           15.924532  17.036444  26.521629  30.585667  32.796251
# AFW           86.082214  85.443014  83.983071  85.305307  86.763667
# AGO           72.255252  71.888639  72.723283  71.277056  72.220269
# ...                 ...        ...        ...        ...        ...
# XKX                 NaN        NaN        NaN        NaN        NaN
# YEM            2.148638   1.709434   1.580226   1.792120   1.743376
# ZAF           16.627822  17.466119  18.363217  18.585950  18.562882
# ZMB           82.982734  82.253158  82.706777  85.135107  86.856529
# ZWE           63.976409  63.740781  64.368292  64.417752  68.527206
#
#                    1995       1996       1997       1998       1999  ...  \
# ...

# %% [markdown]
# (d) Plot the renewable energy usage for South Africa (Country Code: `ZAF`) and the Russian Federation (Country Code: `RUS`) from 1990 to 2018 on the same axes. Include a `title`, `grid` and `legend` in the plot.

# %%
#(d)
energy_data.loc[["ZAF", "RUS"]].T.plot(title="Renewable Energy usage", grid=True, legend=True)
plt.show()

# %% [markdown]
# (e) Display the rows in the data with the 10 highest values in 1990.
#
# Hint: The Pandas [`sort_values` function](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html) can be used.

# %%
#(e)
energy_data.sort_values(by="1990", ascending=False).iloc[:10]
# Out:
#                    1990       1991       1992       1993       1994  \
# Country Code
# TCD           98.163527  98.303706  98.228176  98.173799  98.123684
# ETH           96.635387  96.711289  97.740415  97.198658  96.883886
# UGA           96.018513  96.039330  96.117680  96.228497  96.842455
# BTN           95.898852  95.919938  95.287492  95.858075  95.290964
# BDI           95.200672  94.238663  94.995783  94.907093  95.117960
# NPL           95.119715  94.188648  94.161050  93.545554  92.380242
# TZA           94.784909  94.970588  95.025582  95.147433  95.177636
# BEN           93.703241  94.964848  94.851835  94.988801  94.975035
# CAF           93.494281  93.752248  94.107851  93.814615  93.187639
# BFA           93.158060  93.253823  93.290098  93.479993  93.608094
#
#                    1995       1996       1997       1998       1999  ...  \
# Country Code                                                         ...
# ...

# %% [markdown]
# (f) Extract data for 2018 to a `Series` and use it to display all country codes with missing data for that year. How many countries don't have data for that year?
#
# Hint: the Series [`isna` method](https://pandas.pydata.org/docs/reference/api/pandas.Series.isna.html) can detect missing values.

# %%
#(f)
latest_energy_data = energy_data["2018"]
countries_without_data = list(latest_energy_data[latest_energy_data.isna()].index)
print(countries_without_data)
print(len(countries_without_data))
# Out:
# ['AFE', 'AFW', 'ARB', 'CEB', 'CHI', 'CSS', 'EAP', 'EAR', 'EAS', 'ECA', 'ECS', 'EMU', 'EUU', 'FCS', 'HIC', 'HPC', 'IBD', 'IBT', 'IDA', 'IDB', 'IDX', 'INX', 'LAC', 'LCN', 'LDC', 'LIC', 'LMC', 'LMY', 'LTE', 'MAF', 'MCO', 'MEA', 'MIC', 'MNA', 'NAC', 'OED', 'OSS', 'PRE', 'PSS', 'PST', 'SAS', 'SMR', 'SSA', 'SSF', 'SST', 'TEA', 'TEC', 'TLA', 'TMN', 'TSA', 'TSS', 'UMC', 'WLD']
# 53

# %% [markdown]
# (g) How many countries do have data for 2018?
#
# Hint: the Series [`notna`](https://pandas.pydata.org/docs/reference/api/pandas.Series.notna.html) and [`count`](https://pandas.pydata.org/docs/reference/api/pandas.Series.count.html) methods may be useful here.

# %%
#(g)
latest_energy_data.count()
# Out:
# 213

# %% [markdown]
# (h) Plot a histogram of the data for 2018.
#
# Hint: Pandas DataFrame and Series both have a method for this.

# %%
#(h)
latest_energy_data.plot(kind="hist")
plt.show()

# %% [markdown]
# (i) Save the contents of the DataFrame, created in (c), to a CSV file in your Google Drive account.
#
# To access your Google drive account you first must authorise access using:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# After the above, your Drive can be accessed at the folder `/content/gdrive/My Drive/`.
#
# Hint: Use the DataFrame [`to_csv` method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html)

# %%
#(i)
energy_data.to_csv("/content/gdrive/My Drive/renewable_energy.csv")

# %% [markdown]
# (j) Reload the CSV file from your Google drive account into a new dataframe and check that the values have been reloaded successfuly by comparing the reloaded and original versions.
#
# Hint: Convert both dataframes to numpy arrays using the [`to_numpy` method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_numpy.html) and then compare all values with the numpy [`isclose` function](https://numpy.org/doc/stable/reference/generated/numpy.isclose.html)

# %%
#(j)
reloaded_energy_data = pd.read_csv("/content/gdrive/My Drive/renewable_energy.csv")
reloaded_energy_data = reloaded_energy_data.set_index("Country Code")
np.all(np.isclose(energy_data.to_numpy(), reloaded_energy_data.to_numpy(), equal_nan=True))
# Out:
# True
